# %% [markdown]
# # An Introduction to Social Data Science
#
# ## Lecture Two
#
# ### An Introduction to Python: Part Two
#
# #### 10th August, 2021

# %% [markdown]
# #### Section 2.1: Boolean logic and Control statements
#
# Python allows you to evaluate whether something is ```True``` or ```False```, at least within it's expected logic (which is pretty intuitive most of the time). Once you know how to evaluate a statement you can use this evaluation to control the **flow** in a program. For example, we might say do something if a statement is true and then do something else if another statement applies (This is Boolean logic: a form of algebra in which all values are reduced to either TRUE or FALSE). Python uses two equals signs to mean 'test for equality'. This is not the only way things evaluate to true, but it is the most common one. *Note that a single equals sign signals assignment, not a test for equality*! Can you figure out what's going on in the following set of conditions?

# %%
my_favourite_numbers=[1, 2, 3, 4, 5]

if 13 in my_favourite_numbers:
    print(str(13) + ' is in my list of favourite numbers!')
else:
    print(str(13) + ' is not in my list of favourite numbers!')
# Out:
# 13 is not in my list of favourite numbers!

# %% [markdown]
# Can you figure out why the following prints ```False``` ```True``` ```True```?

# %%
var1 = 4
var2 = "Four"
var3 = 2*2

print(var1 == var2, var1 == var3, var1 != var2)
# Out:
# False True True

# %% [markdown]
# ### Section: 2.1.1 Combing control and loop statements
#
# Now we also combine a control (`if`) statement and a loop statement from above. _Note the double indentation!_ By combining multiple 'parent' and 'child' indentation blocks and statements, we can effectively build a *very* powerful algorithm.

# %%
exList = [1, 3, 6, 7, 15, 533]

for num in exList:   # For every item in our list
    if num%2 == 1:   # If the remainder of dividing by two is one, then:
        print(num, "is an odd number")
    else:
        print(num, "is an even number")
# Out:
# 1 is an odd number
# 3 is an odd number
# 6 is an even number
# 7 is an odd number
# 15 is an odd number
# 533 is an odd number

# %% [markdown]
# We can also nest '```if```' statements in order to control the flow of our code more carefully: within the same indentation we can use mutiple '```elif```' statements as well as an else (to end the control statement - i.e. no more ```elif```s coming. Notice what is printed out for the number six in the statement below:

# %%
exList = [1, 3, 6, 7, 15, 533]

for num in exList:
    if num%2 == 0: 
        print(num, "can be divided by two")  # Note slightly different way of string formatting
    elif num%3 == 0:
        print(num, "can be divided by three")
    else:
        print(num, "is neither divisible by two nor three")
# Out:
# 1 is neither divisible by two nor three
# 3 can be divided by three
# 6 can be divided by two
# 7 is neither divisible by two nor three
# 15 can be divided by three
# 533 is neither divisible by two nor three

# %% [markdown]
# ### Section 2.2: More on Loops
#
# ### Section 2.2.1: Indentations: Recap - outside of control still in for!
#
# A quick recap: it's easy to forget where we are in the indentation **'parent'/'child'** relationship. For example, the following code block prints *every letter* in the loop in such a way that only the letter 'a' is printed in upper case as 'A':

# %%
list1=['a','b','c','a']
 
for i in list1: 
    if i == 'a':
        i = i.upper()
    print(i)
print(i)
# Out:
# A
# b
# c
# A
# A

# %% [markdown]
# ### 2.2.2. Continue and break
#
# Sometimes you need to get out of a loop running a line of code. There are two ways to break this loop. The first, "continue", will return to the top of the loop and start again. The second, "break", will stop the loop entirely.

# %%
for val in "I love open science and reproducible research!":
    if val == "s":
        print('I found an "s"!')
        print('but this isnt a break!')
    elif val == "h":
        print('Ok, Im outta here!')
        break
# Out:
# I found an "s"!
# but this isnt a break!
# I found an "s"!
# but this isnt a break!
# Ok, Im outta here!

# %%
MyString = ''
for val in "lets all join github and responsibily publish our code!":
    if val == "!":
        continue
    MyString = MyString + val
print(MyString)
# Out:
# lets all join github and responsibily publish our code

# %% [markdown]
# ### Section 2.2.3: While
#
# **While** loops are less common than for loops, but they certainly have a place in the Python ecosystem. Generally, a while loop continues to run 'while' it evaluates to true. The danger of while loops is that they may never terminate! Consider the following code as an example of when you might use a for loop, although

# %%
i=0
while i<5:
    print("This will end soon.")
    i=i+1
# Out:
# This will end soon.
# This will end soon.
# This will end soon.
# This will end soon.
# This will end soon.

# %% [markdown]
# Consider the following example of an ```infinite``` while loop. In some circumstances, you may want it to perpetuate forever, but be sure that this is the case if so!
#
# (hint: save your notebook if running the below)

# %%
#************************#
# DANGER, DANGER, DANGER #
#************************#

i=0
while i>=0:
    print("Will this ever end?")
    i=i+1
# Out:
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# Will this ever end?
# ...

# %% [markdown]
# ### Section 2.2.4: List comprehensions
#
# These are one of the most handy features in Python, but they can also be tricky. We are introducing these here because you are likely to see them in code, and you should know what it is you're seeing. The general idea is that when you want to transform elements in a list and return a new list, you can do this in as a 'one-liner' statement. See first the way we already know:

# %%
languages = ['C', 'Python', 'R', 'MATLAB']
bestlanguages = []
for language in languages:
    if language == 'Python':
        bestlanguages.append(language)
    if language == 'R':
        bestlanguages.append(language)        
print(bestlanguages)
# Out:
# ['Python', 'R']

# %% [markdown]
# And now lets do a similar thing via a list comprehension:

# %%
languages = ['C', 'Python', 'R', 'MATLAB']
alllanguages = []
[alllanguages.append(language) for language in languages] # note no assignment
print(alllanguages)
# Out:
# ['C', 'Python', 'R', 'MATLAB']

# %% [markdown]
# ### Section 2.4.1: Advanced List comprehensions
#
# List comprehensions can also include boolean operators (```if``` statements) so that an operation is only done on some elements of a list. Lets now replicate our earlier for loop _exactly_:

# %%
languages = ['C', 'Python', 'R', 'MATLAB']
bestlanguages = [] #reset to empty
[bestlanguages.append(language) for language in languages if language=='R'or language=='Python']
print(bestlanguages)
# Out:
# ['Python', 'R']

# %% [markdown]
# # Section 2.5: User Input and Error Handling
#
# Sometimes you might want input from the user. In the following example, user input will be explored alongside loops and control statements.

# %% [markdown]
# ## Section 2.5.1: User Input

# %%
a = input("Hello! What's your favourite number?")

print("\nThat's amazing! My favourite number is also %s" % int(a))
# Out:
# Hello! What's your favourite number?7
#
# That's amazing! My favourite number is also 7

# %% [markdown]
# ## Section 2.5.2: Error Handling

# %% [markdown]
# But what happens when we put a string into the above? Thats right! A traceback! Introducing 'Error Handling' via ```try``` and ```except``` - this is a method to catch an error that you anticipate happening.

# %%
a = input("Hello! What's your favourite number?")
try:
    print("That's amazing! My favourite number is also %s" % int(a))
except ValueError:
    print("\"%s\" is not a valid integer!" % a)
# Out:
# Hello! What's your favourite number?pizza
# "pizza" is not a valid integer!

# %% [markdown]
# Another example:
# ```python
# x = 1
# y = 0
#
# try:
#     print(x/y)
# except:
#     print("why is this being printed?")
# ```

# %% [markdown]
# #### Section 2.5.3: Advanced Error Handling

# %%
x = 1
y = 0

try:
    print(x/y)
except ZeroDivisionError:
    print("why is this being printed?")
finally:
    print('wuhoh!')
# Out:
# why is this being printed?
# wuhoh!

# %% [markdown]
# Congratulations on making it this far! Have a go at this exercise in the break period, before we talk about Functions and File Inputs

# %% [markdown]
# ### Exercise 2.1
#
# Write the following as a list comprehension:
#
# ```python
# pwrs = []
# for i in range(0,10):
#     pwrs.append(i**i)
# print(pwrs)
# ```

# %%
# Answer Exercise 2.1 here

# %% [markdown]
# ### Exercise 2.2
#
# Write the following as a list comprehension which contains an if condition:
#
# ```
# Tweet = "Who’s Who study sheds new light on power of old boy network - great study by @SamFriedmanSoc @aaronsreeves @LSEnews"
# ```
#
# ```python
# AtMentions = []
# for i in Tweet.split():
#     if i[0] == '@':
#         AtMentions.append(i)
# print(AtMentions)
# ```

# %%
# Answer Exercise 2.2 here

# %% [markdown]
# ### Exercise 2.3
#
# Write a spaceship launch style countdown timer using ```while```. The program should:
#
# 1. Take a number as input from the user (i.e. the number of seconds for the countdown).
# 2. Check that the user input is a number.
# 3. Countdown to zero
# 4. Blastoff!

# %%
# Answer Exercise 2.3 here

# %% [markdown]
# ### Section 2.6: Functions.
#
# #### Section 2.6.1: Introduction to Functions
#
# Perhaps the most important concept that we will cover in this course is the notion of abstraction. To make something more abstract is to articulate or encode some phenomenon in a form that is less contingent or specific. If we can discern the commonalities between different cases, we can apply the same logic in a number of cases.
#
# The functional purpose of programming is typically to transform particular cases into more general ones. Instead of renaming every photo in a set of cat photos, we can append "Cat_" to all of them. In a broader sense, we are trying to automate or abstract tasks with computers in order to play to their strengths for speed and accuracy.
#
# When coding, we prefer abstraction because it gives code a number of advantages:
#
# * easier to re-use
# * more robust
# * more efficient for the coder.
#
# The primary way in which we employ abstraction in programming is the use of the function, f(x) = y. In this case x is some input, f() is a function that is applied to the input and y is the output. Here is a function in python:
#
# ```python
# def greetings():
#     print('hello world')
# ```
#
# This function simply prints the greeting 'hello world'. Now every time we want to say hello world, we could just say greet() instead. It is hardly an improvement, but when you place many reusable lines of code together, then the benefits become obvious.

# %%
def greet():
    print('Are you having a nice day today?')
    print('Oh indubitably! Im really having a really good time in this Python class!')

greet()
# Out:
# Are you having a nice day today?
# Oh indubitably! Im really having a really good time in this Python class!

# %% [markdown]
# Critically, functions can also take an input, operate on it, and then return the result:

# %%
def doubleme(input):
    doublednumber=input*2
    # greet()
    return doublednumber
print(doubleme(2))
# Out:
# 4

# %% [markdown]
# What's going to happen if we comment out the greet() function call above?
#
# Lets try some more functions as examples, including a try except.
#
# First, take a function which accepts strings as inputs:

# %%
def favouritecolour(colour):
    print('My favourite colour is ' + colour)
favouritecolour('green')
# Out:
# My favourite colour is green

# %% [markdown]
# What about if somebody tries to input a number into a function which only accepts strings? Try and except to the rescue!

# %%
def favouritecolour(colour):
    try:
        print('My favourite colour is ' + colour)
    except TypeError:
        print('That cant possibly be a colour...')
favouritecolour(5)
# Out:
# That cant possibly be a colour...

# %% [markdown]
# ### Section 2.6.3: Passing variables around
#
# Parameters to functions are passed by **reference**, not as copies. This means that objects that get modified (specifically here -- reassigned) in the function are permanently changed. See this below example for further exposition:

# %%
def has_1(listIn):
    listIn.sort() 
    return listIn

mylist = [7, 10, 1, 15, 2, 4]

print("The list before it was sorted:\n",mylist)

result = has_1(mylist)

print("\nThe list after it was sorted:\n",result)
# Out:
# The list before it was sorted:
#  [7, 10, 1, 15, 2, 4]
#
# The list after it was sorted:
#  [1, 2, 4, 7, 10, 15]

# %% [markdown]
# ### Section 2.7 Global vs local variables
#
# In python, variables are local if not otherwise declared. This means that when you define variables inside a function indentation, they are `local` to this function by default. While this topic is slightly more advanced and beyond the scope of this module, consider the following:

# %%
def my_favourite_podcast(a_random_statement):
    print(a_random_statement)
    a_random_statement = "But sometimes sports, too."
    print(a_random_statement)

a_random_statement = "I like to listen to data science podcasts"        
my_favourite_podcast(a_random_statement)
print(a_random_statement)
# Out:
# I like to listen to data science podcasts
# But sometimes sports, too.
# I like to listen to data science podcasts

# %% [markdown]
# ### Section 2.7: Abstraction
#
# Functions are most useful when we want to solve a repetitive task efficiently. However, there is a challenge: how do we make the functions general enough, but not too general? So far, we havent seen functions take or return more than one input or output:

# %%
def two_outputs(a):
    b=a+a
    c=a*a
    return b, c

two_outputs(int(5))
# Out:
# (10, 25)

# %% [markdown]
# You can also declare default function inputs, for example like:
#
# ```python
# def two_inputs(input1="burger", input2 = cheeseburger):
#     return input1 + input2
#
# print(two_inputs("cheese","sandwich"))
# ```
# However, Python doesn't like it when the first argument has a default and the second one doesn't (try it yourself).

# %% [markdown]
# You can also declare default function inputs, for example like:
#
# ```python
# def two_inputs(input1="burger", input2 = cheeseburger):
#     return input1 + input2
#
# print(two_inputs("cheese","sandwich"))
# ```
# However, Python doesn't like it when the first argument has a default and the second one doesn't (try it yourself).

# %% [markdown]
# ### Section 2.8: Reading Files
#
# File manipulation is central to the management of data and thus to data analysis. Opening files in python is relatively straightforward. To open a file in python we create a 'file handler'. There are a couple ways of doing this. Most involve the basic format of:
#
# ```python
# filein = open("PATH_TO_FILE",'r'/'w'/'a')
# ```

# %% [markdown]
# ```filein.close()``` closes the file after the operations are complete: it's a good habbit to always close files!

# %% [markdown]
# Open a file and read it line by line:

# %%
filein = open("readme.md",'r')
for i in filein: 
    print(i.strip())
filein.close()
# Out:
# #  :bar_chart: :chart_with_upwards_trend: An Introduction to SDS: Lecture Two :chart_with_downwards_trend: :bar_chart:
#
#
# ![coverage](https://img.shields.io/badge/Purpose-Teaching-blue)
# ![coverage](https://img.shields.io/badge/Language-Python%203.8-red)
# ![coverage](https://img.shields.io/badge/License-MIT-brightgreen)
# ![coverage](https://img.shields.io/badge/Build-passing-yellow)
# ![coverage](https://img.shields.io/badge/Rating-5\5-orange)
# ---
#
# In this first lecture we'll introduce the basics of Python;
#
# 1.) List iterations\
# 2.) Control statements\
# 3.) User defined functions\
# 4.) System arguments\
# 5.) File I/O\
# 6.) Python outside of Jupyter Notebooks\

# %% [markdown]
# One way to guarantee that the file closes is to open it in the following way:
#
# ```python
# with open("readme.md") as filein:
#     print(filein.read())
# ```
#
# Note that the line by line method might be more suitable if we are dealing with very, very large files.

# %% [markdown]
# ### Section 2.9: Writing Files
#
# Writing files is very similar to how you read them. However, you need notice the 'w' (for 'write' parameter in the open() function. Lets save this nursery rhyme to a text file, and then read it in and print it line by line:

# %%
abc = open("data_for_my_next_research_paper.csv",'w')
abc.write('hi, this, is, a, csv, with, some, data')
abc.close()

# %% [markdown]
# Or you can write multiple times, adding to the end of the file.
#
# See this example where we might be iterating over all of the tweets in our twitter database:
#
# ```python
# with open("donaldstweets.txt",'w') as fileout:
#     for tweet in twitter_database:
#         if "@therealdonald" in tweet:
#             newtweet=functioncall(tweet)
#             fileout.write(newtweet)
# ```

# %% [markdown]
# ### Section 2.10: Programming outside Jupyter
#
# There are two main options when it comes to writing code outside of Jupyter notebooks.
#
# ### Section 2.10.1: Integrated Development Environments.
#
# IDEs are coding tools which allow you to write/test/debug your code. They offer features such as completion/insight by highlighting, resource management, debugging tools, etc. They are therefore extremely useful for development. Some of the most commonly used ones are:
#
# 1. Spyder: bundled with the Anaconda distribution, built specifically for data science. Interface similar to RStudio/MATLAB
# 2. PyCharm: also has support for JavaScript, HTML/CSS, Angular JS, Node.js, etc. Full git integration.
# 3. Rodeo: *very* similar to RStudio: divided into text editor, console, environment plot/libraries/files.
#
# ### Section 2.10.2: Text editors
#
# Another option is to use a text editor and then execute the .py files in the command prompt/terminal. This comes in two steps:
#
# 1. Edit code in a text editor (*strongly recommend Atom*)
# 2. Open command window/terminal (Start > Run > "cmd" on Windows, Terminal on Mac/Liunux)
#
# ### Section 2.10.3: Consoles
#
# You can also use the command window/terminal to prototype code on the fly:
#
#     > python

# %% [markdown]
# ### Homework 2.1
#
#
# Build a function which accepts a string as input. Use the functions to count the number of unique letters in each phrase below, and print out the function return (length).
#
# ```python
# phrase_one = "well here we are"
#
# phrase_two = "back in the hot muggy streets of new york"
# ```

# %%
# Answer Homework 2.1 here

# %% [markdown]
# ### Homework 2.2
#
# Construct a function that returns the ingredients for a *great* meal.
#
# ```python
# def my_perfect_dinner(...):
#     ... code to create some delicious eats ...
#     return output
# ```
#
# As a minimum, function inputs should include a drink of your choice, a starter and a main course. If you want to make something like a pizza or sandwich, you will need to specify your toppings or fillings (as a list?). At least some of the function inputs should be non-default (user inputs)!
#
# For the output, you have two choices: i.) get the function to print out a menu or ingredients list, or ii.) return drink+starter+main and print them after the function calls.

# %%
# Answer Homework 2.2 here

# %% [markdown]
# ### Homework 2.3
#
# Save the following Taylor Swift verse as a text file:
#
# ```python
# taylorswift="I dont trust nobody\n
# and nobody trusts me\n
# Ill be the actress\n
# starring in your bad dreams"
# ```
#
# Then read it in, and count the number of lines programatically.
#
# **Can you figure out how to do it as a one-liner?**

# %%
# Answer Homework 2.3 here
